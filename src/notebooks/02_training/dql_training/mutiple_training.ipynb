# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

import sys
sys.path.insert(0, '../../../../')

import numpy as np
import matplotlib.pyplot as plt
import pickle

from src.difsched.config import getExpConfig, visualizeExpConfig
from src.difsched.config import getEnvConfig, visualizeEnvConfig
from src.difsched.env.Hybrid import createEnv
from src.difsched.utils.EnvInterface import EnvInterface
from src.difsched.training import training

# %%
hyperparams = {
    'N_diffusion_steps':30,
    'schedule_type': "vp",
    'abs_action_max': 1.0,
    'gamma': 0.99,
    'lr': 5e-4,
    'decay_lr': True,
    'weight_decay': 0.0,
    'num_critics': 8,
    'lcb_coef': 0.15,
    'q_sample_eta': 1.0,
    'max_q_backup': True,
    'weight_entropy_loss': 0.01,
    'weight_q_loss': 1.0,
    'approximate_action': True,
    'ema_tau': 0.001,
    'ema_period': 20,
    'ema_begin_update': 1000,
    'layer_norm': True,
    'grad_clip': 3.0,
    'device': 'cuda',
}

trainingConfig = {
    #'training_type': 'hybrid',
    'training_type': 'offline',
    'iterations': 100,
    'batch_size': 100,
    'LEN_eval': 50,
    'report_period': 10,
    'len_period': 50,
    'warm_up_period': 50,
    'max_sp_ratio': 1.0,
    'min_sp_ratio': 0.5,
    'max_weight_bc_loss': 1.0,
    'min_weight_bc_loss': 1.0,
    'rb_capacity': 30000
}

offlinDatasetFolder = f'../../../../data/processed/offline_dataset'
trafficDatasetFolder = f'../../../../data/processed/traffic'

# %%
expConfigIdx = 1
expParams = getExpConfig(expConfigIdx)
visualizeExpConfig(expParams)

dataset_off = {
    'observations': [],
    'actions': [],
    'rewards': [],
    'next_observations': []
}

for exp_idx in expParams['offline_dataset_idxs']:
    with open(f'{offlinDatasetFolder}/subOptimalAgent_envConfig{exp_idx}.pkl', 'rb') as f:
        dataset_expert = pickle.load(f)
    
    dataset_off['observations'].extend(dataset_expert['uRecord'])
    dataset_off['actions'].extend(dataset_expert['actionsRecord'])
    dataset_off['rewards'].extend(dataset_expert['rewardRecord'])
    dataset_off['next_observations'].extend(dataset_expert['uNextRecord'])
    
    print(f"Exp {exp_idx} - Avg. packet loss rate: {np.mean(dataset_expert['rewardRecord'])}")
    print(f"Exp {exp_idx} - length of dataset: {len(dataset_expert['uRecord'])}")

print(f"\nCombined dataset length: {len(dataset_off['observations'])}")
print(f"Combined avg. packet loss rate: {np.mean(dataset_off['rewards'])}")



env = createEnv(expParams, trafficDatasetFolder)
env.selectMode(mode="train", type="data")
envInterface = EnvInterface(expParams, discrete_state=False)

# With BC    
save_folder = f"../../../../data/results/dql/config_{expConfigIdx}"
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

training(
    trainingConfig, dataset_off, hyperparams, env, envInterface, save_folder, N_exp_list=[0,1,2]
)
# Out:
# EnvType: HYBRID
# N_user: 20
# LEN_window: 20
# N_aggregation: 4
# dataflow: thumb_fr
# randomSeed: 999
# r_bar: 4
# B: 200
# sigma_list: [0.7, 0.75, 0.8, 0.85, 0.9]
# offline_dataset_idxs: [6, 7, 8]
# Exp 6 - Avg. packet loss rate: 0.012173786552528995
# Exp 6 - length of dataset: 10000
# Exp 7 - Avg. packet loss rate: 0.011216112874385061
# Exp 7 - length of dataset: 10000
# Exp 8 - Avg. packet loss rate: 0.010957690329719938
# Exp 8 - length of dataset: 10000
#
# Combined dataset length: 30000
# Combined avg. packet loss rate: 0.011449196585544667
# 1.0 1.0
# ====================Iteration 10====================
# Ld: 0.23311756685376167, Lq: 0.9869728672504425, Le: -1.520170246362686, loss_Q: 0.0006970254916814156
# Avg. Reward: 0.11709343565929275, sample_ratio: 0.9, weight_bc_loss: 1.0
# ==================================================
# save model 0_best, smoothed reward: 0.08223511948985911
# save model 0_best, smoothed reward: 0.07136793535711554
# save model 0_best, smoothed reward: 0.0676439734559496
# save model 0_best, smoothed reward: 0.05950238484229996
# save model 0_best, smoothed reward: 0.051832730760493204
# save model 0_best, smoothed reward: 0.042382863727978705
# save model 0_best, smoothed reward: 0.0360607159163148
# save model 0_best, smoothed reward: 0.031639291033859075
# save model 0_best, smoothed reward: 0.02770926218909317
# ====================Iteration 20====================
# Ld: 0.2018296854197979, Lq: 0.9925252902507782, Le: -1.4917040622234345, loss_Q: 0.0005173964958521538
# Avg. Reward: 0.039857190478502835, sample_ratio: 0.8, weight_bc_loss: 1.0
# ==================================================
# save model 0_best, smoothed reward: 0.024497059986706895
# save model 0_best, smoothed reward: 0.024425659944700678
# save model 0_best, smoothed reward: 0.023476621167599267
# save model 0_best, smoothed reward: 0.021887309199551494
# save model 0_best, smoothed reward: 0.01948891294818452
# save model 0_best, smoothed reward: 0.019111801345625026
# save model 0_best, smoothed reward: 0.01837703461325134
# ====================Iteration 30====================
# Ld: 0.16198852613568307, Lq: 0.9986685001850129, Le: -1.4473241126537324, loss_Q: 0.00045707824057899415
# Avg. Reward: 0.019100826330885074, sample_ratio: 0.7, weight_bc_loss: 1.0
# ==================================================
# save model 0_best, smoothed reward: 0.01698076870481553
# save model 0_best, smoothed reward: 0.01687194155716521
# save model 0_best, smoothed reward: 0.015579718140883391
# save model 0_best, smoothed reward: 0.014862211828125327
# save model 0_best, smoothed reward: 0.014368497441056068
# ====================Iteration 40====================
# Ld: 0.15883881434798242, Lq: 1.005601277947426, Le: -1.4407571876049041, loss_Q: 0.0005115271033719182
# Avg. Reward: 0.014476564913513141, sample_ratio: 0.6, weight_bc_loss: 1.0
# ==================================================
# ====================Iteration 50====================
# Ld: 0.13809554539620877, Lq: 1.0141911804676056, Le: -1.4098225247859955, loss_Q: 0.00043864131206646564
# Avg. Reward: 0.01733524214844826, sample_ratio: 0.5, weight_bc_loss: 1.0
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 38
#      35 if not os.path.exists(save_folder):
#      36     os.makedirs(save_folder)
# ---> 38 training(
#      39     trainingConfig, dataset_off, hyperparams, env, envInterface, save_folder, N_exp_list=[0,1,2]
#      40 )
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\training\training.py:79, in training(trainingConfig, dataset_off, hyperparams, env, envInterface, save_folder, N_exp_list)
#      77 env.reset()
#      78 env.selectMode(mode="test", type="data")
# ---> 79 reward, _ = eval(agent, env, envInterface, LEN_eval=LEN_eval, obvMode="predicted",
#      80                 sample_method="greedy", N_action_candidates=50, eta=1.0, verbose=True)
#      81 #dataSamplerOn.addOnline(offpolicy_data)
#      82
#      83 #============= Update parameters ==============
#      84 sample_ratio = np.max([min_sp_ratio, max_sp_ratio - ((max_sp_ratio-min_sp_ratio)/warm_up_period) * idx_episode])
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\evaluation\evaluation.py:67, in eval(agent, env, envInterface, LEN_eval, obvMode, mode, type, sample_method, N_action_candidates, eta, verbose)
#      65 info = {'observations': [], 'actions': [], 'rewards': [], 'next_observations': []}
#      66 for window in tqdm(range(LEN_eval), desc="Evaluation windows", leave=False, disable=not verbose):
# ---> 67     u, (w, r, M, alpha), reward, u_next = _step(
#      68         agent, env, envInterface, obvMode, sample_method, N_action_candidates, eta
#      69     )
#      70     #============ Record Results ============
#      71     info['observations'].append(u)
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\evaluation\evaluation.py:38, in _step(agent, env, envInterface, obvMode, sample_method, N_action_candidates, eta)
#      31     a = agent.sample(
#      32         s,
#      33         sample_method="EAS",
#      34         N=N_action_candidates,
#      35         eta = eta
#      36     ).cpu().detach().numpy()[0]
#      37 else:
# ---> 38     a = agent.sample(
#      39         s,
#      40         sample_method=sample_method,
#      41         N=N_action_candidates,
#      42         eta = eta,
#      43     ).cpu().detach().numpy()[0]
#      44 w, r, M, alpha = envInterface.postprocess_action(a)
#      45 reward = env.applyActions(w, r, M, alpha)
#
# File c:\Users\Ye\miniconda3\envs\traffic_predictor_3_9\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\agents\DiffusionQL\DQL_Q_esmb.py:183, in DQL_Q_esmb.sample(self, s, sample_method, N, eta)
#     181 B = s.size(0)
#     182 s_rep = s.unsqueeze(1).expand(B, N, s.size(-1)).reshape(-1, s.size(-1))
# --> 183 a_cand = self.actor.sample_DDIM(s_rep, eta=eta)
#     184 q_cand = self.critic_target.target.q_min(s_rep, a_cand).mean(dim=-1).view(B, N)
#     185 a_cand = a_cand.view(B, N, -1)
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\agents\DiffusionQL\Actors.py:99, in DiffusionPolicy.sample_DDIM(self, s, eta)
#      96 alpha_prev = self.schedule.alpha_bar[step-2] if step > 1 else torch.tensor(1.0, device=s.device)
#      98 t = torch.full((B,), step, device=s.device, dtype=torch.long)
# ---> 99 eps = self(a, s, t)
#     101 sigma_t = eta * ((1 - alpha_prev) / (1 - alpha)).sqrt() * (1 - alpha/alpha_prev).sqrt()
#     102 #sigma_t = eta *(1 - alpha/alpha_prev).sqrt()
#
# File c:\Users\Ye\miniconda3\envs\traffic_predictor_3_9\lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Ye\miniconda3\envs\traffic_predictor_3_9\lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\agents\DiffusionQL\Actors.py:19, in DiffusionPolicy.forward(self, a_t, s, t)
#      18 def forward(self, a_t: torch.Tensor, s: torch.Tensor, t: torch.Tensor) -> torch.Tensor:
# ---> 19     emb = timestep_embedding(t, self.t_dim)
#      20     return self.eps_net(torch.cat([a_t, s, emb], dim=-1))
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\agents\DiffusionQL\Helpers.py:27, in timestep_embedding(t, dim, max_period)
#      25 half = dim // 2
#      26 freq = torch.exp(-math.log(max_period) * torch.arange(half, device=t.device) / half)
# ---> 27 args = t[:, None].float() * freq[None]
#      28 emb = torch.cat([torch.cos(args), torch.sin(args)], dim=-1)
#      29 return F.pad(emb, (0, dim % 2))
#
# KeyboardInterrupt:

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

import sys
sys.path.insert(0, '../../../../')

import numpy as np
import matplotlib.pyplot as plt
import pickle

from src.difsched.config import getExpConfig, visualizeExpConfig
from src.difsched.config import getEnvConfig, visualizeEnvConfig
from src.difsched.env.Hybrid import createEnv
from src.difsched.utils.EnvInterface import EnvInterface
from src.difsched.training import training

# %%
hyperparams = {
    'N_diffusion_steps':15,
    'schedule_type': "vp",
    'abs_action_max': 1.0,
    'gamma': 0.99,
    'lr': 5e-4,
    'decay_lr': True,
    'weight_decay': 0.0,
    'num_critics': 8,
    'lcb_coef': 0.15,
    'q_sample_eta': 1.0,
    'weight_entropy_loss': 0.01,
    'weight_q_loss': 1.0,
    'approximate_action': True,
    'ema_tau': 0.001,
    'ema_period': 20,
    'ema_begin_update': 1000,
    'layer_norm': True,
    'grad_clip': 3.0,
    'device': 'cuda',
}

trainingConfig = {
    #'training_type': 'hybrid',
    'training_type': 'offline',
    'iterations': 100,
    'batch_size': 100,
    'LEN_eval': 50,
    'report_period': 10,
    'len_period': 50,
    'warm_up_period': 50,
    'max_sp_ratio': 1.0,
    'min_sp_ratio': 0.5,
    'max_weight_bc_loss': 1.0,
    'min_weight_bc_loss': 1.0,
    'rb_capacity': 30000
}

offlinDatasetFolder = f'../../../../data/processed/offline_dataset'
trafficDatasetFolder = f'../../../../data/processed/traffic'

# %%
expConfigIdx = 1
expParams = getExpConfig(expConfigIdx)
visualizeExpConfig(expParams)

dataset_off = {
    'observations': [],
    'actions': [],
    'rewards': [],
    'next_observations': []
}

for exp_idx in expParams['offline_dataset_idxs']:
    with open(f'{offlinDatasetFolder}/subOptimalAgent_envConfig{exp_idx}.pkl', 'rb') as f:
        dataset_expert = pickle.load(f)
    
    dataset_off['observations'].extend(dataset_expert['uRecord'])
    dataset_off['actions'].extend(dataset_expert['actionsRecord'])
    dataset_off['rewards'].extend(dataset_expert['rewardRecord'])
    dataset_off['next_observations'].extend(dataset_expert['uNextRecord'])
    
    print(f"Exp {exp_idx} - Avg. packet loss rate: {np.mean(dataset_expert['rewardRecord'])}")
    print(f"Exp {exp_idx} - length of dataset: {len(dataset_expert['uRecord'])}")

print(f"\nCombined dataset length: {len(dataset_off['observations'])}")
print(f"Combined avg. packet loss rate: {np.mean(dataset_off['rewards'])}")



env = createEnv(expParams, trafficDatasetFolder)
env.selectMode(mode="train", type="data")
envInterface = EnvInterface(expParams, discrete_state=False)

# With BC    
save_folder = f"../../../../data/results/dql/config_{expConfigIdx}"
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

training(
    trainingConfig, dataset_off, hyperparams, env, envInterface, save_folder, N_exp_list=[0,1,2]
)
# Out:
# EnvType: HYBRID
# N_user: 20
# LEN_window: 20
# N_aggregation: 4
# dataflow: thumb_fr
# randomSeed: 999
# r_bar: 4
# B: 100
# sigma_list: [0.7, 0.75, 0.8, 0.85, 0.9]
# offline_dataset_idxs: [6, 7, 8]
# Exp 6 - Avg. packet loss rate: 0.01230043260773854
# Exp 6 - length of dataset: 10000
# Exp 7 - Avg. packet loss rate: 0.011260877717562111
# Exp 7 - length of dataset: 10000
# Exp 8 - Avg. packet loss rate: 0.010730114164107494
# Exp 8 - length of dataset: 10000
#
# Combined dataset length: 30000
# Combined avg. packet loss rate: 0.011430474829802714
# 1.0 1.0
# ====================Iteration 10====================
# Ld: 0.23154593244194985, Lq: 0.9872153371572494, Le: -1.158417135477066, loss_Q: 0.0006932368315756321
# Avg. Reward: 0.2756071450859997, sample_ratio: 0.9, weight_bc_loss: 1.0
# ==================================================
# save model 0_best, smoothed reward: 0.2399963565972306
# save model 0_best, smoothed reward: 0.23702717631483378
# save model 0_best, smoothed reward: 0.2209327414991906
# save model 0_best, smoothed reward: 0.2007449860929433
# save model 0_best, smoothed reward: 0.1801073069913687
# save model 0_best, smoothed reward: 0.15903899879398484
# save model 0_best, smoothed reward: 0.13873842526272082
# save model 0_best, smoothed reward: 0.1256209325401877
# save model 0_best, smoothed reward: 0.11321833290775486
# save model 0_best, smoothed reward: 0.09987679446457236
# ====================Iteration 20====================
# Ld: 0.1933235515654087, Lq: 0.9936070543527603, Le: -1.146029850244522, loss_Q: 0.0004904757186886855
# Avg. Reward: 0.13999205072797055, sample_ratio: 0.8, weight_bc_loss: 1.0
# ==================================================
# save model 0_best, smoothed reward: 0.0923953753876865
# save model 0_best, smoothed reward: 0.08440042627661165
# save model 0_best, smoothed reward: 0.07557047564675268
# save model 0_best, smoothed reward: 0.07282838928986338
# save model 0_best, smoothed reward: 0.07088279967656466
# save model 0_best, smoothed reward: 0.06875881219775021
# save model 0_best, smoothed reward: 0.06828579826018008
# ====================Iteration 30====================
# Ld: 0.15150887474417687, Lq: 0.9989484250545502, Le: -1.1238018846511841, loss_Q: 0.00044237567140953616
# Avg. Reward: 0.07238322526836258, sample_ratio: 0.7, weight_bc_loss: 1.0
# ==================================================
# ====================Iteration 40====================
# Ld: 0.1531430397182703, Lq: 1.0048734545707703, Le: -1.121991628408432, loss_Q: 0.000526075929228682
# Avg. Reward: 0.07466325882840906, sample_ratio: 0.6, weight_bc_loss: 1.0
# ==================================================
# save model 0_best, smoothed reward: 0.06709085280476483
# save model 0_best, smoothed reward: 0.06544742959485143
# save model 0_best, smoothed reward: 0.06109794861714589
# save model 0_best, smoothed reward: 0.06088045342828607
# ====================Iteration 50====================
# Ld: 0.13604068577289583, Lq: 1.0127942991256713, Le: -1.1071175253391266, loss_Q: 0.00047416265530046074
# Avg. Reward: 0.06483706739440141, sample_ratio: 0.5, weight_bc_loss: 1.0
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 38
#      35 if not os.path.exists(save_folder):
#      36     os.makedirs(save_folder)
# ---> 38 training(
#      39     trainingConfig, dataset_off, hyperparams, env, envInterface, save_folder, N_exp_list=[0,1,2]
#      40 )
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\training\training.py:74, in training(trainingConfig, dataset_off, hyperparams, env, envInterface, save_folder, N_exp_list)
#      72     dataSamplerOn.addOnline(explore_data)
#      73 elif training_type == 'offline':
# ---> 74     metrics = agent.train(dataSamplerOff, iterations, batch_size, tqdm_pos=0)
#      76 #============= Evaluate ==============
#      77 env.reset()
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\agents\DiffusionQL\DQL_Q_esmb.py:153, in DQL_Q_esmb.train(self, replay_buffer, iterations, batch_size, tqdm_pos)
#     151 batch = replay_buffer.sample(batch_size)
#     152 if batch is not None:
# --> 153     Ld, Lq, Le, loss_Q = self.update(batch)
#     154     metrics["Ld"].append(Ld)
#     155     metrics["Lq"].append(Lq)
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\agents\DiffusionQL\DQL_Q_esmb.py:135, in DQL_Q_esmb.update(self, batch_off, batch_on)
#     133 loss_pi = self.weight_bc_loss*L_bc + self.weight_q_loss * L_q + self.weight_entropy_loss * L_e
#     134 self.optimizer_actor.zero_grad()
# --> 135 loss_pi.backward()
#     136 torch.nn.utils.clip_grad_norm_(self.actor.parameters(), self.grad_clip, norm_type=2)
#     137 self.optimizer_actor.step()
#
# File c:\Users\Ye\miniconda3\envs\traffic_predictor_3_9\lib\site-packages\torch\_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File c:\Users\Ye\miniconda3\envs\traffic_predictor_3_9\lib\site-packages\torch\autograd\__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File c:\Users\Ye\miniconda3\envs\traffic_predictor_3_9\lib\site-packages\torch\autograd\graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

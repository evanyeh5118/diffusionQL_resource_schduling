# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

import sys
sys.path.insert(0, '../../../../')

import numpy as np
import matplotlib.pyplot as plt
import pickle

from src.difsched.config import getExpConfig, visualizeExpConfig
from src.difsched.config import getEnvConfig, visualizeEnvConfig
from src.difsched.env.Hybrid import createEnv
from src.difsched.utils.EnvInterface import EnvInterface
from src.difsched.training import training

# %%
hyperparams = {
    'N_diffusion_steps':20,
    'schedule_type': "vp",
    'abs_action_max': 1.0,
    'gamma': 0.99,
    'lr': 5e-3,
    'decay_lr': True,
    'weight_decay': 0.0,
    'num_critics': 12,
    'lcb_coef': 0.15,
    'q_sample_eta': 1.0,
    'max_q_backup': True,
    'weight_entropy_loss': 0.01,
    'weight_q_loss': 1.0,
    'approximate_action': True,
    'ema_tau': 0.001,
    'ema_period': 20,
    'ema_begin_update': 1000,
    'layer_norm': True,
    'grad_clip': 3.0,
    'device': 'cuda',
}

trainingConfig = {
    #'training_type': 'hybrid',
    'training_type': 'offline',
    'iterations': 100,
    'batch_size': 100,
    'LEN_eval': 50,
    'report_period': 10,
    'len_period': 50,
    'warm_up_period': 50,
    'max_sp_ratio': 1.0,
    'min_sp_ratio': 0.5,
    'max_weight_bc_loss': 1.0,
    'min_weight_bc_loss': 1.0,
    'rb_capacity': 30000
}

offlinDatasetFolder = f'../../../../data/processed/offline_dataset'
trafficDatasetFolder = f'../../../../data/processed/traffic'

# %%
expConfigIdx = 4
expParams = getExpConfig(expConfigIdx)
visualizeExpConfig(expParams)

dataset_off = {
    'observations': [],
    'actions': [],
    'rewards': [],
    'next_observations': []
}

for exp_idx in expParams['offline_dataset_idxs']:
    with open(f'{offlinDatasetFolder}/subOptimalAgent_envConfig{exp_idx}.pkl', 'rb') as f:
        dataset_expert = pickle.load(f)
    
    dataset_off['observations'].extend(dataset_expert['uRecord'])
    dataset_off['actions'].extend(dataset_expert['actionsRecord'])
    dataset_off['rewards'].extend(dataset_expert['rewardRecord'])
    dataset_off['next_observations'].extend(dataset_expert['uNextRecord'])
    
    print(f"Exp {exp_idx} - Avg. packet loss rate: {np.mean(dataset_expert['rewardRecord'])}")
    print(f"Exp {exp_idx} - length of dataset: {len(dataset_expert['uRecord'])}")

print(f"\nCombined dataset length: {len(dataset_off['observations'])}")
print(f"Combined avg. packet loss rate: {np.mean(dataset_off['rewards'])}")



env = createEnv(expParams, trafficDatasetFolder)
env.selectMode(mode="train", type="data")
envInterface = EnvInterface(expParams, discrete_state=False)

# With BC    
save_folder = f"../../../../data/results/dql/config_{expConfigIdx}"
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

training(
    trainingConfig, dataset_off, hyperparams, env, envInterface, save_folder, N_exp_list=[0]
)
# Out:
# EnvType: HYBRID
# N_user: 32
# LEN_window: 20
# N_aggregation: 4
# dataflow: motion_1ms_20
# randomSeed: 999
# r_bar: 4
# B: 320
# sigma_list: [0.7, 0.75, 0.8, 0.85, 0.9]
# offline_dataset_idxs: [9, 10, 11]
# Exp 9 - Avg. packet loss rate: 0.011315806603146631
# Exp 9 - length of dataset: 10000
# Exp 10 - Avg. packet loss rate: 0.008929848579000655
# Exp 10 - length of dataset: 10000
# Exp 11 - Avg. packet loss rate: 0.008517955704454232
# Exp 11 - length of dataset: 10000
#
# Combined dataset length: 30000
# Combined avg. packet loss rate: 0.009587870295533839
# 1.0 1.0
# ====================Iteration 10====================
# Ld: 0.3721536800265312, Lq: 0.987616052031517, Le: -1.2824401009082793, loss_Q: 0.0002887635455408599
# Avg. Reward: 0.3173335559657195, sample_ratio: 0.9, weight_bc_loss: 1.0
# ==================================================
# save model 0_best, smoothed reward: 0.22030801688789575
# save model 0_best, smoothed reward: 0.20540728061571686
# save model 0_best, smoothed reward: 0.1776147102109218
# save model 0_best, smoothed reward: 0.15686735230894677
# save model 0_best, smoothed reward: 0.1257084593127591
# save model 0_best, smoothed reward: 0.10785292597746049
# save model 0_best, smoothed reward: 0.08809692067702846
# save model 0_best, smoothed reward: 0.07722286264251832
# save model 0_best, smoothed reward: 0.062175835278309895
# save model 0_best, smoothed reward: 0.05301530933627697
# ====================Iteration 20====================
# Ld: 0.2899785670638084, Lq: 0.9932804268598556, Le: -1.2825839054584502, loss_Q: 0.00048733093513874336
# Avg. Reward: 0.08936188432451803, sample_ratio: 0.8, weight_bc_loss: 1.0
# ==================================================
# save model 0_best, smoothed reward: 0.045870602242944924
# save model 0_best, smoothed reward: 0.0443155759419534
# save model 0_best, smoothed reward: 0.036554400469868395
# save model 0_best, smoothed reward: 0.03602248001606573
# save model 0_best, smoothed reward: 0.032048795140191856
# save model 0_best, smoothed reward: 0.025472997811911695
# save model 0_best, smoothed reward: 0.023236648683179796
# save model 0_best, smoothed reward: 0.021685542586900593
# ====================Iteration 30====================
# Ld: 0.19118986800312995, Lq: 1.0065934002399444, Le: -1.1771277236938475, loss_Q: 0.00027016899664886293
# Avg. Reward: 0.027554692877027498, sample_ratio: 0.7, weight_bc_loss: 1.0
# ==================================================
# save model 0_best, smoothed reward: 0.02133701982686129
# ====================Iteration 40====================
# Ld: 0.21961770638823508, Lq: 0.982754076719284, Le: -1.2105946362018585, loss_Q: 0.029584058899490628
# Avg. Reward: 0.024336663761336783, sample_ratio: 0.6, weight_bc_loss: 1.0
# ==================================================
# save model 0_best, smoothed reward: 0.01776016875137411
# ====================Iteration 50====================
# Ld: 0.1756250973045826, Lq: 1.0109918665885926, Le: -1.144282978773117, loss_Q: 0.0004188933194382116
# Avg. Reward: 0.02034421738093623, sample_ratio: 0.5, weight_bc_loss: 1.0
# ==================================================

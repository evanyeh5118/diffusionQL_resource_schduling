# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

import sys
sys.path.insert(0, '../../../../')

import numpy as np
import matplotlib.pyplot as plt
import pickle

from fig01_helper import plot_two_groups, load_reward_curves

# %%
paths_forward = [f'config_0', f'config_0/without_bc']
paths_backward = [f'config_1', f'config_1/without_bc']  # Updated: config_1 doesn't exist yet
idxs_forward = range(3)
idxs_backward = range(3)

models_dir = "../../../data/results/dql"

# Load data for both sets
print("Loading forward data...")
reward_curves_forward = load_reward_curves(paths_forward, idxs_forward, models_dir=models_dir)

print("Loading backward data...")
reward_curves_backward = load_reward_curves(paths_backward, idxs_backward, models_dir=models_dir)

# Prepare data for plotting
reward_curves_forward_list = [reward_curves_forward[lb] for lb in paths_forward]
reward_curves_backward_list = [reward_curves_backward[lb] for lb in paths_backward]

# Labels for forward curves
labels_forward = ['w/ Expert', 'w/o Expert']
labels_final_forward = ['w/ Expert', 'w/o Expert']

# Labels for backward curves
labels_backward = ['Config 10 (Avg.)', 'Without BC (Avg.)']
labels_final_backward = ['Expert (Final)', 'Without BC (Final)']


# Plot both sets on the same figure
print("Creating combined plot...")
fig = plot_two_groups(
    curves_list1=reward_curves_forward_list,
    labels1=labels_forward,
    curves_list2=reward_curves_backward_list,
    labels2=labels_backward,
    figsize=(11, 3),
    title1="8 Users",
    title2="20 Users",
    title_fontsize=25,
    label_fontsize=22,
    tick_fontsize=20,
    legend_fontsize=20
)

# Save the figure
output_path = 'combined_training_curves.png'
plt.savefig(output_path, dpi=300, bbox_inches='tight')
print(f"Figure saved as: {output_path}")


targetFolder = "C:/Users/Ye/Documents/YuYeh_Documents/L2S/Conference_Writing/ICC_2_diffusionQL_shedule/Figures"
fig.savefig(os.path.join(targetFolder, "train_curve_haptic.png"), dpi=300, bbox_inches='tight')
# Out:
# Loading forward data...
# Loading backward data...
# Creating combined plot...
# Figure saved as: combined_training_curves.png

# %%
from tkinter import W


paths_forward = [f'config_2', f'config_2/without_bc']
paths_backward = [f'config_3', f'config_3/without_bc']
idxs_forward = range(3)
idxs_backward = range(3)

# Load data for both sets
print("Loading forward data...")
reward_curves_forward = load_reward_curves(paths_forward, idxs_forward, models_dir=models_dir)

print("Loading backward data...")
reward_curves_backward = load_reward_curves(paths_backward, idxs_backward, models_dir=models_dir)

# Prepare data for plotting
reward_curves_forward_list = [reward_curves_forward[lb] for lb in paths_forward]
reward_curves_backward_list = [reward_curves_backward[lb] for lb in paths_backward]

# Labels for forward curves
labels_forward = ['w/ Expert', 'w/o Expert']
labels_final_forward = ['w/ Expert', 'w/o Expert']

# Labels for backward curves
labels_backward = ['w/ BC', 'w/o BC']
labels_final_backward = ['w/ BC', 'w/o BC']


# Plot both sets on the same figure
print("Creating combined plot...")
fig = plot_two_groups(
    curves_list1=reward_curves_forward_list,
    labels1=labels_forward,
    curves_list2=reward_curves_backward_list,
    labels2=labels_backward,
    figsize=(11, 3),
    title1="8 Users",
    title2="20 Users",
    title_fontsize=25,
    label_fontsize=22,
    tick_fontsize=20,
    legend_fontsize=20
)

# Save the figure
output_path = 'combined_training_curves.png'
plt.savefig(output_path, dpi=300, bbox_inches='tight')
print(f"
292, 0.43858344766967006, 0.40780876028156854, 0.38160465533433485, 0.3854119801745552, 0.3686009676708288, 0.42785167548000624, 0.39269916830975937, 0.3895337999843004, 0.3775657658504626, 0.3998678373213781, 0.36972855301126173, 0.3738263811270265, 0.4017940788291953, 0.3784613367931785, 0.37562150664601524, 0.39999864349227393, 0.35932629807083427, 0.3608027651786637, 0.36432351668687324, 0.3788496151139837, 0.3708224192525128, 0.3513839460676669, 0.37563628059695087, 0.35620504477329057, 0.3868347622811417, 0.37207649569913215, 0.3803814281421165, 0.36564954161895413, 0.363721103336131, 0.3744826043362689, 0.37333087864639225, 0.3875520972717893, 0.37291553449475606, 0.37349499727044455, 0.3589520080626245, 0.37382241917500925, 0.36030547720017586]}, {'exp_0': [0.7532419249829644, 0.7262880615424702, 0.7134781131094455, 0.736627222189767, 0.7141280267082071, 0.7615188331442299, 0.7406164333570139, 0.7534122508011886, 0.7163074060990933, 0.7368023734326172, 0.7132159481649519, 0.7327936196929754, 0.7567316380950488, 0.721578348423733, 0.7274396605098034, 0.7423199055458254, 0.7170573227601007, 0.7134922127610202, 0.7160431161998027, 0.663084802901977, 0.6444682700317301, 0.6022646271716304, 0.6307767589681359, 0.6075483767411018, 0.5932138849848861, 0.5943635394665605, 0.5827900127811674, 0.5999068685270433, 0.588554782445826, 0.6190751027527508, 0.551051428331533, 0.6211702126159192, 0.5793017358322277, 0.5540981475652952, 0.5698414903161965, 0.5566479849260565, 0.5743335556419676, 0.5981070940459465, 0.5646951364654197, 0.5937908388493431, 0.5759703918279903, 0.5519807636263072, 0. ...

# %%
'''
# Example: single plot for forward curves only
import matplotlib.pyplot as plt

# Set up figure and axis
fig, ax = plt.subplots(figsize=(8, 4))

# Set plot parameters
title = "Motion Flow"
title_fontsize = 20
label_fontsize = 20
tick_fontsize = 15
legend_fontsize = 15

# Plot only the forward group
visualize_reward_curves_grouped(
    curves_list=reward_curves_forward_list,
    labels=labels_forward,
    ax=ax,
    title=title,
    show_legend=True,
    title_fontsize=title_fontsize,
    label_fontsize=label_fontsize,
    tick_fontsize=tick_fontsize,
    legend_fontsize=legend_fontsize
)

plt.tight_layout()
plt.show()
'''
# Out:
# '\n# Example: single plot for forward curves only\nimport matplotlib.pyplot as plt\n\n# Set up figure and axis\nfig, ax = plt.subplots(figsize=(8, 4))\n\n# Set plot parameters\ntitle = "Motion Flow"\ntitle_fontsize = 20\nlabel_fontsize = 20\ntick_fontsize = 15\nlegend_fontsize = 15\n\n# Plot only the forward group\nvisualize_reward_curves_grouped(\n    curves_list=reward_curves_forward_list,\n    labels=labels_forward,\n    ax=ax,\n    title=title,\n    show_legend=True,\n    title_fontsize=title_fontsize,\n    label_fontsize=label_fontsize,\n    tick_fontsize=tick_fontsize,\n    legend_fontsize=legend_fontsize\n)\n\nplt.tight_layout()\nplt.show()\n'

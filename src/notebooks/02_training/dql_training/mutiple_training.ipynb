# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

import sys
sys.path.insert(0, '../../../../')

import numpy as np
import matplotlib.pyplot as plt
import pickle

from src.difsched.config import getExpConfig, visualizeExpConfig
from src.difsched.config import getEnvConfig, visualizeEnvConfig
from src.difsched.env.Hybrid import createEnv
from src.difsched.utils.EnvInterface import EnvInterface
from src.difsched.training import training

# %%
hyperparams = {
    'N_diffusion_steps':30,
    'schedule_type': "vp",
    'abs_action_max': 1.0,
    'gamma': 0.99,
    'lr': 5e-4,
    'decay_lr': True,
    'weight_decay': 0.0,
    'num_critics': 8,
    'lcb_coef': 0.15,
    'q_sample_eta': 1.0,
    'weight_entropy_loss': 0.01,
    'weight_q_loss': 1.0,
    'approximate_action': True,
    'ema_tau': 0.001,
    'ema_period': 20,
    'ema_begin_update': 1000,
    'layer_norm': True,
    'grad_clip': 3.0,
    'device': 'cuda',
}

WithoutBchyperparams = {
    'N_diffusion_steps':30,
    'schedule_type': "vp",
    'abs_action_max': 1.0,
    'gamma': 0.99,
    'lr': 5e-3,
    'decay_lr': True,
    'weight_decay': 0.0,
    'num_critics': 8,
    'lcb_coef': 0.01,
    'q_sample_eta': 1.0,
    'weight_entropy_loss': 0.01,
    'weight_q_loss': 1.0,
    'approximate_action': True,
    'ema_tau': 0.001,
    'ema_period': 20,
    'ema_begin_update': 1000,
    'layer_norm': True,
    'grad_clip': 3.0,
    'device': 'cuda',
}

trainingConfig = {
    'BC_loss': True,
    'iterations': 100,
    'batch_size': 100,
    'LEN_eval': 50,
    'report_period': 10,
    'len_period': 50,
    'warm_up_period': 50,
    'max_sp_ratio': 1.0,
    'min_sp_ratio': 0.5,
    'max_weight_bc_loss': 1.0,
    'min_weight_bc_loss': 1.0,
    'rb_capacity': 30000
}

trainingWithoutBcConfig = {
    'BC_loss': False,
    'iterations': 100,
    'batch_size': 100,
    'LEN_eval': 50,
    'report_period': 10,
    'len_period': 50,
    'warm_up_period': 50,
    'max_sp_ratio': 0.01,
    'min_sp_ratio': 0.01,
    'max_weight_bc_loss': 1.0,
    'min_weight_bc_loss': 1.0,
    'rb_capacity': 30000
}

datasetFolder = f'../../../../data/processed/offline_dataset'

# %%
expConfigIdx = 0
expParams = getExpConfig(expConfigIdx)
visualizeExpConfig(expParams)

dataset_off = {
    'observations': [],
    'actions': [],
    'rewards': [],
    'next_observations': []
}

for exp_idx in expParams['offline_dataset_idxs']:
    with open(f'{datasetFolder}/subOptimalAgent_envConfig{exp_idx}.pkl', 'rb') as f:
        dataset_expert = pickle.load(f)
    
    dataset_off['observations'].extend(dataset_expert['uRecord'])
    dataset_off['actions'].extend(dataset_expert['actionsRecord'])
    dataset_off['rewards'].extend(dataset_expert['rewardRecord'])
    dataset_off['next_observations'].extend(dataset_expert['uNextRecord'])
    
    print(f"Exp {exp_idx} - Avg. packet loss rate: {np.mean(dataset_expert['rewardRecord'])}")
    print(f"Exp {exp_idx} - length of dataset: {len(dataset_expert['uRecord'])}")

print(f"\nCombined dataset length: {len(dataset_off['observations'])}")
print(f"Combined avg. packet loss rate: {np.mean(dataset_off['rewards'])}")
# Out:
# EnvType: HYBRID
# N_user: 8
# LEN_window: 200
# N_aggregation: 4
# dataflow: thumb_fr
# randomSeed: 999
# r_bar: 4
# B: 40
# sigma_list: [0.7, 0.75, 0.8, 0.85, 0.9]
# offline_dataset_idxs: [0, 1, 2]
# Exp 0 - Avg. packet loss rate: 0.005324583513922976
# Exp 0 - length of dataset: 10000
# Exp 1 - Avg. packet loss rate: 0.005114059207268933
# Exp 1 - length of dataset: 10000
# Exp 2 - Avg. packet loss rate: 0.005186708550076399
# Exp 2 - length of dataset: 10000
#
# Combined dataset length: 30000
# Combined avg. packet loss rate: 0.005208450423756103

# %%
expConfigIdx = 0
expParams = getExpConfig(expConfigIdx)
visualizeExpConfig(expParams)

dataset_off = {
    'observations': [],
    'actions': [],
    'rewards': [],
    'next_observations': []
}

for exp_idx in expParams['offline_dataset_idxs']:
    with open(f'{datasetFolder}/subOptimalAgent_envConfig{exp_idx}.pkl', 'rb') as f:
        dataset_expert = pickle.load(f)
    
    dataset_off['observations'].extend(dataset_expert['uRecord'])
    dataset_off['actions'].extend(dataset_expert['actionsRecord'])
    dataset_off['rewards'].extend(dataset_expert['rewardRecord'])
    dataset_off['next_observations'].extend(dataset_expert['uNextRecord'])
    
    print(f"Exp {exp_idx} - Avg. packet loss rate: {np.mean(dataset_expert['rewardRecord'])}")
    print(f"Exp {exp_idx} - length of dataset: {len(dataset_expert['uRecord'])}")

print(f"\nCombined dataset length: {len(dataset_off['observations'])}")
print(f"Combined avg. packet loss rate: {np.mean(dataset_off['rewards'])}")


trafficDataParentPath = f'../../../../data/processed/traffic'
env = createEnv(expParams, trafficDataParentPath)
env.selectMode(mode="train", type="data")
envInterface = EnvInterface(expParams, discrete_state=False)

# With BC    
save_folder = f"../../../../data/results/dql/config_{expConfigIdx}"
if not os.path.exists(save_folder):
    os.makedirs(save_folder)

training(
    trainingConfig, dataset_off, hyperparams, env, envInterface, save_folder, N_exp_list=[0,1,2]
)
# Out:
# EnvType: HYBRID
# N_user: 8
# LEN_window: 200
# N_aggregation: 4
# dataflow: thumb_fr
# randomSeed: 999
# r_bar: 4
# B: 40
# sigma_list: [0.7, 0.75, 0.8, 0.85, 0.9]
# offline_dataset_idxs: [0, 1, 2]
# Exp 0 - Avg. packet loss rate: 0.005324583513922976
# Exp 0 - length of dataset: 10000
# Exp 1 - Avg. packet loss rate: 0.005114059207268933
# Exp 1 - length of dataset: 10000
# Exp 2 - Avg. packet loss rate: 0.005186708550076399
# Exp 2 - length of dataset: 10000
#
# Combined dataset length: 30000
# Combined avg. packet loss rate: 0.005208450423756103
# 1.0 1.0
# Expert's Reward: 0.9947795867919922
# state_dim: 8, action_dim: 18
# ====================Iteration 10====================
# Ld: 0.06887225661426782, Lq: 0.9934873521327973, Le: -1.4682375168800355, loss_Q: 0.0012457949308736715
# Avg. Reward: 0.03621655366052496, sample_ratio: 0.9, weight_bc_loss: 1.0
# ==================================================
# save model 0_best, smoothed reward: 0.021109427416764175
# save model 0_best, smoothed reward: 0.018396962927047476
# save model 0_best, smoothed reward: 0.014455544294846369
# save model 0_best, smoothed reward: 0.013414772676586468
# save model 0_best, smoothed reward: 0.012457319019141004
# save model 0_best, smoothed reward: 0.008846072096147782
# save model 0_best, smoothed reward: 0.007026209267282365
# ====================Iteration 20====================
# Ld: 0.05706121627241373, Lq: 0.9996835029125214, Le: -1.432372978925705, loss_Q: 0.0010023658262798562
# Avg. Reward: 0.01215073197893059, sample_ratio: 0.8, weight_bc_loss: 1.0
# ==================================================
# save model 0_best, smoothed reward: 0.005842101184146228
# ====================Iteration 30====================
# Ld: 0.039317215085029604, Lq: 1.0071495962142945, Le: -1.4137949073314666, loss_Q: 0.0010906517988769338
# Avg. Reward: 0.006304128850749556, sample_ratio: 0.7, weight_bc_loss: 1.0
# ==================================================
# save model 0_best, smoothed reward: 0.0048868191511524705
# ====================Iteration 40====================
# Ld: 0.04322823692113161, Lq: 1.0156270003318786, Le: -1.4059575045108794, loss_Q: 0.0011729301564628257
# Avg. Reward: 0.006692335458294665, sample_ratio: 0.6, weight_bc_loss: 1.0
# ==================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 38
#      35 if not os.path.exists(save_folder):
#      36     os.makedirs(save_folder)
# ---> 38 training(
#      39     trainingConfig, dataset_off, hyperparams, env, envInterface, save_folder, N_exp_list=[0,1,2]
#      40 )
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\training\training.py:66, in training(trainingConfig, dataset_off, hyperparams, env, envInterface, save_folder, N_exp_list)
#      62 _, explore_data = eval(agent, env, envInterface, LEN_eval=LEN_eval, obvMode="predicted",
#      63                     sample_method="exploration", N_action_candidates=10,
#      64                     eta=np.random.uniform(0.5, 3.0), verbose=True)
#      65 dataSamplerOn.addOnline(explore_data)
# ---> 66 reward, offpolicy_data = eval(agent, env, envInterface, LEN_eval=LEN_eval, obvMode="predicted",
#      67                             sample_method="greedy", N_action_candidates=50, eta=1.0, verbose=True)
#      68 dataSamplerOn.addOnline(offpolicy_data)
#      69 sample_ratio = np.max([min_sp_ratio, max_sp_ratio - ((max_sp_ratio-min_sp_ratio)/warm_up_period) * idx_episode])
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\evaluation\evaluation.py:67, in eval(agent, env, envInterface, LEN_eval, obvMode, mode, type, sample_method, N_action_candidates, eta, verbose)
#      65 info = {'observations': [], 'actions': [], 'rewards': [], 'next_observations': []}
#      66 for window in tqdm(range(LEN_eval), desc="Evaluation windows", leave=False, disable=not verbose):
# ---> 67     u, (w, r, M, alpha), reward, u_next = _step(
#      68         agent, env, envInterface, obvMode, sample_method, N_action_candidates, eta
#      69     )
#      70     #============ Record Results ============
#      71     info['observations'].append(u)
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\evaluation\evaluation.py:38, in _step(agent, env, envInterface, obvMode, sample_method, N_action_candidates, eta)
#      31     a = agent.sample(
#      32         s,
#      33         sample_method="EAS",
#      34         N=N_action_candidates,
#      35         eta = eta
#      36     ).cpu().detach().numpy()[0]
#      37 else:
# ---> 38     a = agent.sample(
#      39         s,
#      40         sample_method=sample_method,
#      41         N=N_action_candidates,
#      42         eta = eta,
#      43     ).cpu().detach().numpy()[0]
#      44 w, r, M, alpha = envInterface.postprocess_action(a)
#      45 reward = env.applyActions(w, r, M, alpha)
#
# File c:\Users\Ye\miniconda3\envs\traffic_predictor_3_9\lib\site-packages\torch\utils\_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\agents\DiffusionQL\DQL_Q_esmb.py:181, in DQL_Q_esmb.sample(self, s, sample_method, N, eta)
#     179 B = s.size(0)
#     180 s_rep = s.unsqueeze(1).expand(B, N, s.size(-1)).reshape(-1, s.size(-1))
# --> 181 a_cand = self.actor.sample_DDIM(s_rep, eta=eta)
#     182 q_cand = self.critic_target.target.q_min(s_rep, a_cand).mean(dim=-1).view(B, N)
#     183 a_cand = a_cand.view(B, N, -1)
#
# File c:\Users\Ye\Documents\YuYeh_Documents\L2S\Projects\NetSoft_Hybrid_scheduling_diffusion\diffusionQL_resource_schduling\src\notebooks\02_training\dql_training\../../../..\src\difsched\agents\DiffusionQL\Actors.py:103, in DiffusionPolicy.sample_DDIM(self, s, eta)
#     101 sigma_t = eta * ((1 - alpha_prev) / (1 - alpha)).sqrt() * (1 - alpha/alpha_prev).sqrt()
#     102 #sigma_t = eta *(1 - alpha/alpha_prev).sqrt()
# --> 103 x0_pred = alpha_prev.sqrt() * (a - (1-alpha).sqrt() * eps) / alpha.sqrt()
#     104 direct_point_x = (1 - alpha_prev - sigma_t.pow(2)).clamp(0.0).sqrt() * eps
#     105 noise_term = sigma_t * noises[step - 1]
#
# KeyboardInterrupt:
